# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha1365/TECHNICAL_TRAINING_CTS/blob/main/02_11_2022_Gray_scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image_color = mpimg.imread('/content/MicrosoftTeams-image.jpg')

# %%
plt.imshow(image_color);

# %%
image_copy = np.copy(image_color)
image_copy.shape
# Out:
# (406, 612, 3)

# %%
image_copy[ (image_copy[:,:,0] < 250) | (image_copy[:,:,1] < 200) |
           (image_copy[:,:,2] < 200) ] = 0

# %%
plt.imshow(image_copy, cmap = 'gray')
plt.show()
