# %% [markdown]
# <a href="https://colab.research.google.com/github/nisha1365/TECHNICAL_TRAINING_CTS/blob/main/02_11_2022_Masking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image_color = mpimg.imread('/content/MicrosoftTeams-image.jpg')

# %%
plt.imshow(image_color);

# %%
image_gray = cv2.cvtColor(image_color,cv2.COLOR_BGR2GRAY)





plt.imshow(image_gray,cmap='gray');
image_gray.shape
# Out:
# (406, 612)

# %%
image_copy = np.copy(image_gray)
image_copy.shape
# Out:
# (406, 612)

# %%
image_copy[ (image_copy[:,:] < 250)] = 0 # any value that is not white

# %%
plt.imshow(image_copy, cmap='gray')
plt.show()
